# %% [markdown]
# # De l'ETL aux Analyses de Marché et Conformité RGP

# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
from sqlalchemy import text

# %% [markdown]
# ## Connexion à MySQL

# %%
engine = create_engine('mysql+pymysql://root:Motdepasse95@localhost/ecommerce_warehouse')

# %% [markdown]
# ## Chargement des données

# %%
data = pd.read_csv('./closed_data_for_business_analysis/data/InputData.csv')
display(data.head())
data.shape
# Out:
#          Date         ProductName  ProductCategory ProductSubCategory  \
# 0  2023-09-14           Nathaniel      Electronics             Camera
# 1  2023-02-11  NonExistentProduct      Electronics             Mobile
# 2  2021-11-12              Angela  InvalidCategory     Action Figures
# 3  11-15-2021                 Amy    Home & Garden              Decor
# 4  2023-04-22           Nathaniel      Electronics             Camera
#
#   ProductPrice     CustomerName                   CustomerEmail  \
# 0         0.01    Colleen Kelly           maryhurst@example.org
# 1       847.43      Joel Wright     sandersvictoria@example.org
# 2       386.57    Thomas Sawyer             ospence@example.net
# 3       364.01    Tyler Gardner  christopherjohnson@example.com
# 4       652.35  Meagan Peterson             epowell@example.net
#
#                                  CustomerAddress           CustomerPhone  \
# 0  354 Mcdowell Turnpike, Port Charles, CT 95318       908.610.2711x8507
# 1       24740 Fox Villages, New Tracie, MA 53038     +1-408-938-0389x952
# 2            769 Joe Trail, East Terri, CA 43813  001-929-516-1919x39288
# 3  27783 Olivia Centers, Williamsmouth, AL 09809              8907712983
# 4    25357 Blackwell Locks, Andreabury, MH 27857              9999921886
#
#   CustomerSegment  ...    SupplierContact ShipperName ShippingMethod  \
# 0          Silver  ...         6538306661    and Sons         Ground
# 1            Gold  ...                NaN         PLC            Air
# 2            Gold  ...    +1-588-750-7646         PLC            Sea
# 3            Gold  ...  805-650-6257x5876         LLC            Air
# 4            Gold  ...         6538306661         Ltd            Sea
#
#   QuantitySold TotalAmount  DiscountAmount  NetAmount  StockReceived  \
# 0           49    31965.15          121.07   31844.08            475
# 1           73    61862.39           91.09   61771.30            487
# 2           89    34404.73           10.56   34394.17            341
# 3            3     1092.03           69.06    1022.97            500
# 4           75    48926.25          137.17   48789.08            429
#
#    StockSold  StockOnHand
# 0        127          348
# 1        243          244
# 2        188          153
# 3        124          376
# 4        351           78
#
# [5 rows x 22 columns]
# (5010, 22)

# %% [markdown]
# ## Transformations des données (Traitement)

# %% [markdown]
# ### Valeurs manquantes

# %%
data.fillna({'ProductPrice': 0, 'QuantitySold': 0, 'StockReceived': 0, 'StockSold': 0, 'StockOnHand': 0,
             'CustomerEmail': 'NonExistentCustomerEmail', 'CustomerPhone': 'NonExistentCustomerPhone', 'SupplierContact': 'NonExistentSupplierContact'}, inplace=True)

# %% [markdown]
# ### Conversion des dates

# %%
data['Date'] = pd.to_datetime(data['Date'], errors='coerce', infer_datetime_format=True)
# Out:
# /var/folders/jn/b7dhfkqd7pq8llfc7crg3gqw0000gp/T/ipykernel_26931/1077770489.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   data['Date'] = pd.to_datetime(data['Date'], errors='coerce', infer_datetime_format=True)

# %% [markdown]
# ### Splittling : Extractions des dimensions depuis l'input

# %% [markdown]
# #### Chargement des dimensions

# %%
try:
    # Insertion dans Dim_Produit
    dim_produit = data[['ProductName', 'ProductCategory', 'ProductSubCategory']].drop_duplicates()
    for row in dim_produit.itertuples(index=False):
        query = text("""
            INSERT INTO Dim_Produit (ProductName, ProductCategory, ProductSubCategory)
            VALUES (:ProductName, :ProductCategory, :ProductSubCategory)
            ON DUPLICATE KEY UPDATE ProductName = VALUES(ProductName)
        """)
        with engine.connect() as conn:
            conn.execute(query, {
                'ProductName': row.ProductName,
                'ProductCategory': row.ProductCategory,
                'ProductSubCategory': row.ProductSubCategory
            })
            conn.commit()

    # Insertion dans Dim_Client
    dim_client = data[['CustomerSegment']].drop_duplicates()
    for row in dim_client.itertuples(index=False):
        query = text("""
            INSERT INTO Dim_Client (CustomerSegment)
            VALUES (:CustomerSegment)
            ON DUPLICATE KEY UPDATE CustomerSegment = VALUES(CustomerSegment)
        """)
        with engine.connect() as conn:
            conn.execute(query, {'CustomerSegment': row.CustomerSegment})
            conn.commit()

    # Insertion dans Dim_Fournisseur
    dim_fournisseur = data[['SupplierName', 'SupplierLocation', 'SupplierContact']].drop_duplicates()
    for row in dim_fournisseur.itertuples(index=False):
        query = text("""
            INSERT INTO Dim_Fournisseur (SupplierName, SupplierLocation, SupplierContact)
            VALUES (:SupplierName, :SupplierLocation, :SupplierContact)
            ON DUPLICATE KEY UPDATE SupplierName = VALUES(SupplierName)
        """)
        with engine.connect() as conn:
            conn.execute(query, {
                'SupplierName': row.SupplierName,
                'SupplierLocation': row.SupplierLocation,
                'SupplierContact': row.SupplierContact
            })
            conn.commit()

    # Insertion dans Dim_Transporteur
    dim_transporteur = data[['ShipperName', 'ShippingMethod']].drop_duplicates()
    for row in dim_transporteur.itertuples(index=False):
        query = text("""
            INSERT INTO Dim_Transporteur (ShipperName, ShippingMethod)
            VALUES (:ShipperName, :ShippingMethod)
            ON DUPLICATE KEY UPDATE ShipperName = VALUES(ShipperName)
        """)
        with engine.connect() as conn:
            conn.execute(query, {
                'ShipperName': row.ShipperName,
                'ShippingMethod': row.ShippingMethod
            })
            conn.commit()

    # Insertion dans Dim_Date
    date_fictive = pd.DataFrame({
        'Date': [pd.to_datetime('1900-01-01')],
        'Year': [1900],
        'Month': [1],
        'Day': [1]
    })
    
    dates_valides = data[['Date']].drop_duplicates().dropna()
    dates_valides['Year'] = dates_valides['Date'].dt.year
    dates_valides['Month'] = dates_valides['Date'].dt.month
    dates_valides['Day'] = dates_valides['Date'].dt.day

    dim_date = pd.concat([dates_valides, date_fictive], ignore_index=True)

    dim_date.to_sql('Dim_Date', con=engine, if_exists='append', index=False)

except Exception as e:
    print(f"Erreur chargement dimensions : {e}")

# %% [markdown]
# #### Chargement des faits

# %%
import pandas as pd
from sqlalchemy import text

# 📌 Vérifier et insérer la date fictive si elle n'existe pas
with engine.connect() as conn:
    conn.execute(text("""
        INSERT INTO Dim_Date (Date, Year, Month, Day) 
        VALUES ('1900-01-01', 1900, 1, 1)
        ON DUPLICATE KEY UPDATE Date = VALUES(Date);
    """))
    conn.commit()

# 📌 Récupérer la clé de la date fictive
date_fictive_key = pd.read_sql(
    "SELECT DateKey FROM Dim_Date WHERE Date = '1900-01-01'", engine
).iloc[0, 0]

# 📌 Initialisation des listes pour stocker les données avant insertion
sales_fact_data = []
inventory_fact_data = []

for _, row in data.iterrows():
    try:
        # 📌 Vérification et récupération de la date
        date_key = date_fictive_key
        if pd.notnull(row['Date']):
            result = pd.read_sql(
                f"SELECT DateKey FROM Dim_Date WHERE Date = '{row['Date'].date()}'", engine
            )
            if not result.empty:
                date_key = result.iloc[0, 0]

        # 📌 Récupération des clés étrangères
        product_result = pd.read_sql(
            f"SELECT ProductKey FROM Dim_Produit WHERE ProductName = '{row['ProductName']}'",
            engine
        )
        product_key = product_result.iloc[0, 0] if not product_result.empty else None

        client_result = pd.read_sql(
            f"SELECT CustomerKey FROM Dim_Client WHERE CustomerSegment = '{row['CustomerSegment']}'",
            engine
        )
        client_key = client_result.iloc[0, 0] if not client_result.empty else None

        supplier_result = pd.read_sql(
            f"SELECT SupplierKey FROM Dim_Fournisseur WHERE SupplierName = '{row['SupplierName']}'",
            engine
        )
        supplier_key = supplier_result.iloc[0, 0] if not supplier_result.empty else None

        shipper_result = pd.read_sql(
            f"SELECT ShipperKey FROM Dim_Transporteur WHERE ShipperName = '{row['ShipperName']}'",
            engine
        )
        shipper_key = shipper_result.iloc[0, 0] if not shipper_result.empty else None

        # 📌 Vérification et gestion des valeurs NULL pour `SalesFact`
        if None not in (product_key, client_key, supplier_key, shipper_key):
            sales_fact_data.append((
                date_key, product_key, client_key, supplier_key, shipper_key,
                row['QuantitySold'], row['TotalAmount'], row['DiscountAmount'], row['NetAmount']
            ))

        # 📌 Vérification et gestion des valeurs NULL pour `InventoryFact`
        if None not in (product_key, supplier_key):
            inventory_fact_data.append((
                date_key, product_key, supplier_key,
                row['StockReceived'], row['StockSold'], row['StockOnHand']
            ))

    except Exception as e:
        print(f"Erreur sur ligne : {e}")

# 📌 Conversion en DataFrame et insertion dans la base
if sales_fact_data:
    sales_fact_df = pd.DataFrame(sales_fact_data, columns=[
        'DateKey', 'ProductKey', 'CustomerKey', 'SupplierKey', 'ShipperKey',
        'QuantitySold', 'TotalAmount', 'DiscountAmount', 'NetAmount'
    ])
    sales_fact_df.to_sql('SalesFact', con=engine, if_exists='append', index=False, chunksize=1000)

if inventory_fact_data:
    inventory_fact_df = pd.DataFrame(inventory_fact_data, columns=[
        'DateKey', 'ProductKey', 'SupplierKey', 'StockReceived', 'StockSold', 'StockOnHand'
    ])
    inventory_fact_df.to_sql('InventoryFact', con=engine, if_exists='append', index=False, chunksize=1000)
# Out:
# Chargement de `SalesFact` et `InventoryFact` terminé.

# %% [markdown]
# ## Export des données

# %% [markdown]
# ### Export en csv

# %%
output_path = 'closed_data_for_business_analysis/outputs/'

dim_produit.to_csv(output_path+'dim_produit.csv', index=False)
dim_client.to_csv(output_path+'dim_client.csv', index=False)
dim_fournisseur.to_csv(output_path+'dim_fournisseur.csv', index=False)
dim_transporteur.to_csv(output_path+'dim_transporteur.csv', index=False)
dim_date.to_csv(output_path+'dim_date.csv', index=False)

sales_fact_df.to_csv(output_path + 'sales_fact.csv', index=False)
inventory_fact_df.to_csv(output_path + 'inventory_fact.csv', index=False)
